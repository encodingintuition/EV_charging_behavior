# %% [markdown]
# # Charging Station Behavior
# ### Georgia Tech EV Charging Station transactions and miles driven
# link: https://www.kaggle.com/claytonmiller/campus-electric-vehicle-charging-stations-behavior
# git https://github.com/Sheldon-Zhang/Gatech_EV_Analytics
# <hr>

# %% [markdown]
# Contents
# - [test]()
# - (test)[#Feature-Creation]

# %% [markdown]
# # Imports
# <hr>

# %%
# Imports

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter
import seaborn as sns
# set figure size 
sns.set(rc={'figure.figsize':(21,9)})

# nan
import missingno as msno

# %%
# var

dict_dayofweek = { 0 : 'Monday', 1 :'Tuesday', 2 : 'Wednesday', 3 : 'Thursday', 4 : 'Friday', 5: 'Saturday', 6 : 'Sunday'}

# %% [markdown]
# # Data Ingestion
# <hr>

# %%
# reading in data - EV-Charging-Raw-Data
df = pd.read_csv('../data/ev_charging_datasets/Georga_EV_charge_behavior/EV-Charging-Raw-Data.csv')

# %%
df.shape
# Out:
# (1530, 30)

# %%
df.head(3)
# Out:
#   Label 01 Lable 02      Org Name       Start Date Start Time Zone  \
# 0        A        A  Georgia Tech  2/13/2015 13:30             EST
# 1        A        A  Georgia Tech  2/13/2015 12:47             EST
# 2        A        A  Georgia Tech  2/13/2015 11:50             EST
#
#           End Date End Time Zone Transaction Date (Pacific Time)  \
# 0  2/13/2015 14:42           EST                 2/13/2015 11:46
# 1  2/13/2015 13:45           EST                 2/13/2015 10:46
# 2  2/13/2015 13:02           EST                 2/13/2015 10:04
#
#   Total Duration (hh:mm:ss) Charging Time (hh:mm:ss)  ...  Postal Code  \
# 0                   1:12:10                  1:11:50  ...        30308
# 1                   0:58:39                  0:58:15  ...        30308
# 2                   1:11:40                  1:11:24  ...        30308
#
#          Country  Label 07 Label 08  Currency   Fee             Ended By  \
# 0  United States         A        A       USD  1.02  Plug Out at Vehicle
# 1  United States         A        A       USD  0.83             Customer
# 2  United States         A        A       USD  1.02  Plug Out at Vehicle
#
#   Plug In Event Id Driver Postal Code   User ID
# 0              540              30102  254811.0
# 1              539              30269  323807.0
# 2              538              30253  345151.0
#
# [3 rows x 30 columns]

# %%
df.tail(3)
# Out:
#      Label 01 Lable 02      Org Name       Start Date Start Time Zone  \
# 1527        A        A  Georgia Tech   2/13/2015 6:35             EST
# 1528        A        A  Georgia Tech  2/13/2015 15:03             EST
# 1529        A        A  Georgia Tech   2/13/2015 7:43             EST
#
#      End Date End Time Zone Transaction Date (Pacific Time)  \
# 1527      NaN           EST                             NaN
# 1528      NaN           EST                             NaN
# 1529      NaN           EST                             NaN
#
#      Total Duration (hh:mm:ss) Charging Time (hh:mm:ss)  ...  Postal Code  \
# 1527                   9:05:05                  6:38:01  ...        30308
# 1528                   0:35:09                  0:34:44  ...        30308
# 1529                   7:55:25                  7:36:11  ...        30308
#
#             Country  Label 07 Label 08  Currency  Fee Ended By  \
# 1527  United States         A        A       NaN  0.0      NaN
# 1528  United States         A        A       NaN  0.0      NaN
# 1529  United States         A        A       NaN  0.0      NaN
#
#      Plug In Event Id Driver Postal Code   User ID
# 1527              791              30114  235945.0
# 1528       1423857773              30345  183185.0
# 1529              792              30622  217113.0
#
# [3 rows x 30 columns]

# %%
df.columns
# Out:
# Index(['Label 01', 'Lable 02', 'Org Name', 'Start Date', 'Start Time Zone',
#        'End Date', 'End Time Zone', 'Transaction Date (Pacific Time)',
#        'Total Duration (hh:mm:ss)', 'Charging Time (hh:mm:ss)', 'Energy (kWh)',
#        'GHG Savings (kg)', 'Gasoline Savings (gallons)', 'Port Type',
#        'Port Number', 'Plug Type', 'Label 03', 'Label 04', 'Label 05',
#        'Label 06', 'Postal Code', 'Country', 'Label 07', 'Label 08',
#        'Currency', 'Fee', 'Ended By', 'Plug In Event Id', 'Driver Postal Code',
#        'User ID'],
#       dtype='object')

# %% [markdown]
# #
# <hr>

# %% [markdown]
# #### Unique Values per Feature

# %%
# See how many unique entries is in each numerical feature 
unique_values = df.select_dtypes(include= 'number').nunique().sort_values()

# Plot unique values with a y-axis in log-scale
unique_values.plot.bar(logy=True, figsize = (15,4), title='Unique values per Feature');

# %% [markdown]
# <br>

# %% [markdown]
# #### Check for duplicates

# %%
# Check number of duplicates
n_duplicates = df.duplicated().sum()
print(f"You seem to have {n_duplicates} duplicates in your database.")

#  Extract column names of all features
columns_to_consider = df.columns

# Drop duplicates based on 'columns_to_consider'
df_X = df.drop_duplicates(subset=columns_to_consider)
df_X.shape
# Out:
# You seem to have 0 duplicates in your database.
# (1530, 30)

# %%
# check duplicates
dif = set(df.index) - set(df_X.index) 
dif
# Out:
# set()

# %% [markdown]
# <br>

# %% [markdown]
# #### Nan

# %%
msno.matrix(df);

# %%
msno.bar(df);

# %%
# Fill Nan in 'Driver Postal Code', 'User ID' with 0

df['Driver Postal Code'] = df['Driver Postal Code'].fillna(0)
df['User ID'] = df['User ID'].fillna(0)

# %% [markdown]
# <br>

# %% [markdown]
# #### Numerical Features

# %%
# 

df.plot(lw=0,
    marker='.',
    subplots=True,
    layout=(-1,4),
    figsize=(15,15),
    markersize=1);

# %% [markdown]
# <br>

# %% [markdown]
# #### Non-Numerical Features

# %%
# number of non-numerical features
df.select_dtypes(exclude=["number", "datetime"]).shape
# Out:
# (1530, 22)

# %%
# Create figure object with 3 subplots
fig, axes = plt.subplots(ncols=1, nrows=22, figsize=(12, 45))

# Identify non-numerical features
df_non_numerical = df.select_dtypes(exclude=["number", "datetime"])

# Loop through features and put each subplot on a matplotlib axis object
for col, ax in zip(df_non_numerical.columns, axes.ravel()):

    # Selects one single feature and counts number of unique value
    df_non_numerical[col].value_counts().plot(

        # Plots this information in a figure with log-scaled y-axis
        logy=True, title=col, lw=0, marker=".", ax=ax)
    
plt.tight_layout();

# %%
 df_non_numerical = df[['Start Date', 'End Date', 'Transaction Date (Pacific Time)',
 'Total Duration (hh:mm:ss)', 'Charging Time (hh:mm:ss)']]


 for col, ax in zip(df_non_numerical.columns, axes.ravel()):

    # Selects one single feature and counts number of unique value
    df_non_numerical[col].value_counts().plot(

        # Plots this information in a figure with log-scaled y-axis
        logy=True, title=col, lw=0, marker=".", ax=ax)
    
plt.tight_layout();

# %% [markdown]
# #### Feature Distrobution

# %%
# Plots the histogram for each numerical feature in a separate subplot
df.hist(bins=25, figsize=(15, 5), layout=(-1, 5), edgecolor="black")
plt.tight_layout();

# %% [markdown]
# #### Continuous Features

# %%
# continouous colums seen in 'Unique values per Feature graph'
cols_continuous = ['Fee','Plug In Event Id','Gasoline Savings (gallons)','GHG Savings (kg)', 'Energy (kWh)', 'User ID']

# Create a new dataframe which only contains the continuous features
df_continuous = df[cols_continuous]
df_continuous.shape
# Out:
# (1530, 6)

# %%
"""# Pair plot of continuous features

sns.pairplot(df_continuous, height=1.5,
             plot_kws={"s": 2, "alpha": 0.2});"""
# Out:
# '# Pair plot of continuous features\n\nsns.pairplot(df_continuous, height=1.5,\n             plot_kws={"s": 2, "alpha": 0.2});'

# %%
df['User ID'].drop_duplicates(subset='Driver Postal Code')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-764-c9d0aa7d2233> in <module>
# ----> 1 df['User ID'].drop_duplicates(subset='Driver Postal Code')
#
# TypeError: drop_duplicates() got an unexpected keyword argument 'subset'

# %%
df[df['User ID'].drop_duplicates(subset='Driver Postal Code') == 250315.0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-763-b4e3a3602cb7> in <module>
# ----> 1 df[df['User ID'].drop_duplicates(subset='Driver Postal Code') == 250315.0]
#
# TypeError: drop_duplicates() got an unexpected keyword argument 'subset'

# %%
# deeper pair plot investigation

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1530 entries, 0 to 1529
# Data columns (total 30 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Label 01                         1530 non-null   object
#  1   Lable 02                         1530 non-null   object
#  2   Org Name                         1530 non-null   object
#  3   Start Date                       1530 non-null   object
#  4   Start Time Zone                  1530 non-null   object
#  5   End Date                         1527 non-null   object
#  6   End Time Zone                    1530 non-null   object
#  7   Transaction Date (Pacific Time)  1525 non-null   object
#  8   Total Duration (hh:mm:ss)        1530 non-null   object
#  9   Charging Time (hh:mm:ss)         1530 non-null   object
#  10  Energy (kWh)                     1530 non-null   float64
#  11  GHG Savings (kg)                 1530 non-null   float64
#  12  Gasoline Savings (gallons)       1530 non-null   float64
#  13  Port Type                        1530 non-null   object
#  14  Port Number                      1530 non-null   int64
#  15  Plug Type                        1530 non-null   object
#  16  Label 03                         1530 non-null   object
#  17  Label 04                         1530 non-null   object
#  18  Label 05                         1530 non-null   object
#  19  Label 06                         1530 non-null   object
#  20  Postal Code                      1530 non-null   int64
#  21  Country                          1530 non-null   object
#  22  Label 07                         1530 non-null   object
#  23  Label 08                         1530 non-null   object
#  24  Currency                         1527 non-null   object
#  25  Fee                              1530 non-null   float64
#  26  Ended By                         1523 non-null   object
#  27  Plug In Event Id                 1530 non-null   int64
#  28  Driver Postal Code               1530 non-null   object
#  29  User ID                          1530 non-null   float64
# dtypes: float64(5), int64(3), object(22)
# memory usage: 358.7+ KB

# %%
df.head(1).T
# Out:
#                                                    0
# Label 01                                           A
# Lable 02                                           A
# Org Name                                Georgia Tech
# Start Date                           2/13/2015 13:30
# Start Time Zone                                  EST
# End Date                             2/13/2015 14:42
# End Time Zone                                    EST
# Transaction Date (Pacific Time)      2/13/2015 11:46
# Total Duration (hh:mm:ss)                    1:12:10
# Charging Time (hh:mm:ss)                     1:11:50
# Energy (kWh)                                   6.249
# GHG Savings (kg)                               2.625
# Gasoline Savings (gallons)                     0.784
# Port Type                                    Level 2
# Port Number                                        1
# Plug Type                                      J1772
# Label 03                                           A
# Label 04                                           A
# Label 05                                          A
# Label 06                                           A
# Postal Code                                    30308
# Country                                United States
# Label 07                                           A
# Label 08                                           A
# Currency                                         USD
# Fee                                             1.02
# Ended By                         Plug Out at Vehicle
# Plug In Event Id                                 540
# Driver Postal Code                             30102
# User ID                                       254811

# %% [markdown]
# <hr>

# %% [markdown]
# ### Reading in other file

# %%
# !ls ../data/ev_charging_datasets/Georga_EV_charge_behavior
# Out:
# Campus EV Charging Behavior Study.pdf Driving_Distance.xlsx
# DataAnalytics.m                       EV-Charging-Raw-Data.csv
# Driving_Distance.csv                  README.md

# %%
# data table with distences from home zip code to charging zip code
df2 = pd.read_csv('../data/ev_charging_datasets/Georga_EV_charge_behavior/Driving_Distance.csv')

# %%
df2.shape
# Out:
# (84, 3)

# %%
df2.head()
# Out:
#     From     To       km
# 0  30308  28207  362.076
# 1  30308  30002   10.766
# 2  30308  30004   42.394
# 3  30308  30005   38.345
# 4  30308  30009   34.898

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   From    84 non-null     int64
#  1   To      84 non-null     int64
#  2   km      84 non-null     float64
# dtypes: float64(1), int64(2)
# memory usage: 2.1 KB

# %% [markdown]
# <br>

# %% [markdown]
# # Nan Inspection
# <hr>

# %%
msno.matrix(df)

# %%
msno.bar(df)

# %% [markdown]
# # nan

# %% [markdown]
# # Feature Creation
# <hr>

# %%
# A slice of the data frame 
#    - 

df = df[['Start Date',
'Total Duration (hh:mm:ss)',
'Charging Time (hh:mm:ss)',
'GHG Savings (kg)',
'Energy (kWh)',
'Port Type',
'Plug Type',
'Gasoline Savings (gallons)',
'Postal Code',
'Ended By',
'Fee',
'Driver Postal Code',
'User ID']].copy()

df.head(3)
# Out:
#         Start Date Total Duration (hh:mm:ss) Charging Time (hh:mm:ss)  \
# 0  2/13/2015 13:30                   1:12:10                  1:11:50
# 1  2/13/2015 12:47                   0:58:39                  0:58:15
# 2  2/13/2015 11:50                   1:11:40                  1:11:24
#
#    GHG Savings (kg)  Energy (kWh) Port Type Plug Type  \
# 0             2.625         6.249   Level 2     J1772
# 1             1.828         4.352   Level 2     J1772
# 2             1.823         4.341   Level 2     J1772
#
#    Gasoline Savings (gallons)  Postal Code             Ended By   Fee  \
# 0                       0.784        30308  Plug Out at Vehicle  1.02
# 1                       0.546        30308             Customer  0.83
# 2                       0.545        30308  Plug Out at Vehicle  1.02
#
#   Driver Postal Code   User ID
# 0              30102  254811.0
# 1              30269  323807.0
# 2              30253  345151.0

# %%
# set start time to datetime format
df['Start Date'] = pd.to_datetime(df['Start Date'])

# %%
# create a column with day of the week 
df['day_of_week'] = df['Start Date'].dt.dayofweek
# creats a column with week
df['week'] = df['Start Date'].dt.week
# convert int to sting of days of week, monday, tuesday, wednesday ... 
df.replace({'day_of_week' : dict_dayofweek}, inplace = True)

# creats a column with month
df['month'] = df['Start Date'].dt.month

# creats a column with hour
df['hour'] = df['Start Date'].dt.hour
# creates a varable to count numer of events that day
df['count_event'] = 1

# %%
# !ls ../clean_data
# Out:
# GATECH-CB-clean.csv       all_EV_stations-clean.csv

# %%
# Write clean new Dataset to CSV

df.to_csv('../clean_data/GATECH-CB-clean.csv',  index = False)

# %% [markdown]
# <br>

# %% [markdown]
# #### DateTime Manipulaton

# %%
# DateTime Manipulation 
#       - set Time to index
df.set_index('Start Date', inplace = True)
df.sort_index(inplace = True)

# %%
# Create dataframe for visualization

# duplicate df
df_graph = df.copy()
# create sum per WEEK
df_graph = df_graph.resample('w').sum()

# %%
type(df.index[1])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
""""
playing with time in date time to graph it 

"""


##   df['date'] = df.index.dt.date
##   df['time'] = pd.to_datetime('timestamp')

#    df['time'] = 
#    df.index.strftime("%H.%M")
# Out:
# '"\nplaying with time in date time to graph it \n\n'

# %% [markdown]
# <br>

# %% [markdown]
# ## Quick Exploration
# <hr>
# <br>

# %% [markdown]
# #### Dates

# %%
df.index.min()
# Out:
# Timestamp('2014-01-03 16:51:00')

# %%
df.index.max()
# Out:
# Timestamp('2015-02-13 15:03:00')

# %%
df.index.max() - df.index.min()
# Out:
# Timedelta('405 days 22:12:00')

# %% [markdown]
#         Dates 1/03/2014 - 2/13/2015
#         405 days in total

# %% [markdown]
# #### Port Type

# %%
df['Port Type'].value_counts()
# Out:
# Level 2    1530
# Name: Port Type, dtype: int64

# %% [markdown]
#                 All ports are Level 2

# %% [markdown]
# #### Plug Type

# %%
df['Plug Type'].value_counts()
# Out:
# J1772    1530
# Name: Plug Type, dtype: int64

# %% [markdown]
#                 All plugs are J1772

# %% [markdown]
# #### Ended By

# %%
df['Ended By'].value_counts()
# Out:
# Plug Out at Vehicle             1088
# Customer                         312
# CPS Server                        64
# Timeout                           58
# Plug Removed While Rebooting       1
# Name: Ended By, dtype: int64

# %% [markdown]
# <br>

# %% [markdown]
# #### GHG Savings

# %%
df['GHG Savings (kg)'].describe()
# Out:
# count    1530.000000
# mean        3.906703
# std         2.758232
# min         0.000000
# 25%         2.265250
# 50%         3.751000
# 75%         5.198750
# max        35.862000
# Name: GHG Savings (kg), dtype: float64

# %% [markdown]
# <br>

# %% [markdown]
# #### Postal code

# %%
df['Postal Code'].value_counts()
# Out:
# 30308    1530
# Name: Postal Code, dtype: int64

# %% [markdown]
#                 All are postal code 30308

# %% [markdown]
# #### Driver Postal Codes

# %%
df['Driver Postal Code'].value_counts().plot(kind='bar', figsize = (21,9))
# Axis labels
plt.xlabel("Postal Code", fontsize = 18)
plt.ylabel("count", fontsize = 12)
plt.title('NUmber of events per Driver Postal Code', fontsize = 27)
# Out:
# Text(0.5, 1.0, 'NUmber of events per Driver Postal Code')

# %%
# Top 1/3 of Driver Postal Code 

print(len(pd.unique(df['Driver Postal Code'])) / 3 )

# Variable - index zip code , [1] counts
top_third_driverPostalCode = df['Driver Postal Code'].value_counts().sort_values(axis=0, ascending = False).head(27)

# Graph 
df['Driver Postal Code'].value_counts().sort_values(axis=0, ascending = False).head(27).plot(kind='bar', figsize = (21,9))

plt.xlabel("Postal Code", fontsize = 18)
plt.ylabel("count", fontsize = 12)
plt.suptitle('NUmber of events per Driver Postal Code', fontsize = 27);
plt.title('top 30 %', fontsize = 18);
# Out:
# 28.666666666666668

# %%
# Cleans up 'Driver Postal Code' from NANs and other random 

Driver_Postal_Code = []

for x in df['Driver Postal Code'].dropna():
    if len(x) == 5:
        Driver_Postal_Code.append(int(x))

# displays count of each zip code 
zipcode, count = np.unique(Driver_Postal_Code,return_counts=True) 

tempData = { 'zipcode': zipcode, 'count': count}
df_driverZip = pd.DataFrame(tempData)
df_driverZip = df_driverZip.sort_values(by = 'count', ascending= False).reset_index(drop = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-729-71f064242ab0> in <module>
#       4
#       5 for x in df['Driver Postal Code'].dropna():
# ----> 6     if len(x) == 5:
#       7         Driver_Postal_Code.append(int(x))
#       8
#
# TypeError: object of type 'int' has no len()

# %% [markdown]
# <br>

# %% [markdown]
# #### User ID

# %% [markdown]
# *** issue

# %%
# number of unique User_ID
df['User ID'].nunique()
# Out:
# 179

# %%
# create a data frame with user_ID and their count of session per id
userid, count = np.unique(df['User ID'], return_counts= True)
# create dataframe, empty 
df_userid = pd.DataFrame({ 'user_id': userid, 'count': count})
# sort values in dataframe
df_userid = df_userid.sort_values(by = 'count', ascending= False).reset_index(drop = True)
df_userid

# %%
# Merge User_ID with corrisoponding zip codes
df_userid = pd.merge(df_userid, df[['Driver Postal Code', 'User ID']].drop_duplicates(subset='Driver Postal Code'),
                     left_on='user_id', right_on='User ID', how = 'left', validate='1:m')

# %%
df_userid.head(12)
# Out:
#      user_id  count Driver Postal Code   User ID
# 0        0.0    132                  0       0.0
# 1   217113.0    102              30622  217113.0
# 2   235945.0     92              30114  235945.0
# 3   200169.0     69              30360  200169.0
# 4   206089.0     60              30075  206089.0
# 5   254811.0     58              30102  254811.0
# 6   261355.0     57              30062  261355.0
# 7   209813.0     52              30308  209813.0
# 8   223923.0     40              30097  223923.0
# 9   250315.0     36                NaN       NaN
# 10  211289.0     34              30506  211289.0
# 11  269487.0     34                NaN       NaN

# %%
# MEAN, STD number of chargin session per user_id
df_userid['count'].agg(['mean','std'])
# Out:
# mean     8.547486
# std     17.864714
# Name: count, dtype: float64

# %%
# number of charging sessions per user_ID
sns.boxplot(data=df_userid,x='count');

# %%
# number of charging sessions per user_ID, WHERE count < 20

sns.histplot(data=df_userid[df_userid['count'] < 20],x='count', bins = 25);

# %%
# Where is the Nan coming from 

df_userid.head(20)
# Out:
#      user_id  count Driver Postal Code   User ID
# 0        0.0    132                  0       0.0
# 1   217113.0    102              30622  217113.0
# 2   235945.0     92              30114  235945.0
# 3   200169.0     69              30360  200169.0
# 4   206089.0     60              30075  206089.0
# 5   254811.0     58              30102  254811.0
# 6   261355.0     57              30062  261355.0
# 7   209813.0     52              30308  209813.0
# 8   223923.0     40              30097  223923.0
# 9   250315.0     36                NaN       NaN
# 10  211289.0     34              30506  211289.0
# 11  269487.0     34                NaN       NaN
# 12  260891.0     34                NaN       NaN
# 13  183185.0     32              30345  183185.0
# 14  254595.0     31                NaN       NaN
# 15  241607.0     28                NaN       NaN
# 16  323807.0     28                NaN       NaN
# 17  178553.0     27              30542  178553.0
# 18  300523.0     23              30346  300523.0
# 19  206351.0     22              30096  206351.0

# %% [markdown]
# <br>

# %% [markdown]
# #### Energy per Week

# %%
# Bar plot - sum of energy per week

sns.set(rc={'figure.figsize':(21,9),"font.size":20,"axes.titlesize":20,"axes.labelsize":20})

ax = sns.barplot(data = df, x = 'week', y = 'Energy (kWh)', 
       hue = 'Port Type',estimator=np.sum, palette = 'mako')

ax.set(xlabel="week",
       ylabel="Energy in (kWh)",
       title="Sum of Energy per Week For 2014",
       )
;
# Out:
# ''

# %%
# Bar plot - sum of energy per month

sns.set(rc={'figure.figsize':(21,9),"font.size":20,"axes.titlesize":20,"axes.labelsize":20})

ax = sns.barplot(data = df, x = 'month', y = 'Energy (kWh)', 
       hue = 'Port Type',estimator=np.sum, palette = 'mako')

ax.set(xlabel="Month",
       ylabel="Energy in (kWh)",
       title="Sum of Energy per Month For 2014",
       )
;
# Out:
# ''

# %%
# Bar plot - sum of energy by day of week

sns.set(rc={'figure.figsize':(21,9),"font.size":20,"axes.titlesize":20,"axes.labelsize":20})

ax = sns.barplot(data = df, x = 'day_of_week', y = 'Energy (kWh)', 
       hue = 'Port Type',estimator=np.sum, palette = 'mako',
       order = ['Monday','Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])

ax.set(xlabel="Day of the Week",
       ylabel="Energy in (kWh)",
       title="Sum of Energy by Day of Week For 2014",
       )
;
# Out:
# ''

# %%
# Bar plot - sum of energy by hour of the day

sns.set(rc={'figure.figsize':(21,9),"font.size":20,"axes.titlesize":20,"axes.labelsize":20})

ax = sns.barplot(data = df, x = 'hour', y = 'Energy (kWh)', 
       estimator=np.sum, palette = 'mako'
              )

ax.set(xlabel="Hour of the day",
       ylabel="Energy in (kWh)",
       title="Sum of Energy per hour of the day For 2014",
       )
;
# Out:
# ''

# %%
# Bar plot - sum of energy by hour of the day

sns.set(rc={'figure.figsize':(21,9),"font.size":20,"axes.titlesize":20,"axes.labelsize":20})

ax = sns.barplot(data = df, x = 'hour', y = 'Energy (kWh)', 
       hue = 'day_of_week',estimator=np.sum, palette = 'mako'
              )

ax.set(xlabel="Hour of the day",
       ylabel="Energy in (kWh)",
       title="Sum of Energy per hour of the day For 2014",
       )
;
# Out:
# ''

# %%
# Bar plot - Average of energy by hour of the day

sns.set(rc={'figure.figsize':(21,9),"font.size":20,"axes.titlesize":20,"axes.labelsize":20})

ax = sns.barplot(data = df, x = 'hour', y = 'Energy (kWh)', 
       hue = 'day_of_week',estimator=np.mean, palette = 'mako')

ax.set(xlabel="Hour of the day",
       ylabel="Energy in (kWh)",
       title="Average of Energy per hour of the day For 2014",
       )
;
# Out:
# ''

# %% [markdown]
#             6 - 8am have the hihest sum of kWh but all hours have close to the same avg kWh per hours.
#
#             This makes me feel 6 - 8am has a higher count of charges, more traffic.

# %%
sns.set(rc={'figure.figsize':(21,9),"font.size":20,"axes.titlesize":20,"axes.labelsize":20})

ax = sns.histplot(data = df, x = 'hour', bins = 24)

ax.set(xlabel="Hour of the day",
       ylabel="count",
       title="Number events per hour,for 2014",)
# Out:
# [Text(0, 0.5, 'count'),
#  Text(0.5, 0, 'Hour of the day'),
#  Text(0.5, 1.0, 'Number events per hour,for 2014')]

# %%
# It would be nice to show all days of the week in an animation with the abilty to right click 


sns.barplot(
    data = df[ df['day_of_week'] == 'Tuesday' ],
    x = 'hour',
    y = 'Energy (kWh)',
    estimator = np.sum,
    palette = "icefire"
    );

# %% [markdown]
# create 3d visualization
# end is sum

# %% [markdown]
# #### Energy Usage

# %%
# Sum of Energy per Day For 2014

sns.set(rc={'figure.figsize':(21,9),"font.size":20,"axes.titlesize":20,"axes.labelsize":20})


# figure 

ax = sns.lineplot(x = df_graph.index, y = df_graph['Energy (kWh)'], color = 'green'
        )
ax2 = plt.twinx()
ax = sns.lineplot(x = df_graph.index, y = df_graph['count_event'], ax = ax2, color = 'orange')

ax.set(xlabel="Date",
       ylabel="Energy in (kWh)",
       title="Sum of Energy per Week For 2014",
       xlim=["2014-01-01", "2014-12-31"])
       
ax2.set_ylabel("Charging Events",color="orange",fontsize=18)

# have before DateFormatter       
ax.set_xticklabels(df_graph.index, rotation=45, horizontalalignment='right')
# date format
date_form = DateFormatter("%m/%d")
ax.xaxis.set_major_formatter(date_form)

# tick once every other week (interval=2) 
ax.xaxis.set_major_locator(mdates.WeekdayLocator(interval=2))

## 
# axs.set_ylabel('mylabel',size=6)
#fig, ax = plt.subplots(figsize = (21,9))

;
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axis.py in convert_units(self, x)
#    1572         try:
# -> 1573             ret = self.converter.convert(x, self.units, self)
#    1574         except Exception as e:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/dates.py in convert(value, unit, axis)
#    1920         """
# -> 1921         return date2num(value)
#    1922
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/dates.py in date2num(d)
#     436             return d
# --> 437         return _to_ordinalf_np_vectorized(d)
#     438
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/lib/function_base.py in __call__(self, *args, **kwargs)
#    2090
# -> 2091         return self._vectorize_call(func=func, args=vargs)
#    2092
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/lib/function_base.py in _vectorize_call(self, func, args)
#    2160         else:
# -> 2161             ufunc, otypes = self._get_ufunc_and_otypes(func=func, args=args)
#    2162
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/lib/function_base.py in _get_ufunc_and_otypes(self, func, args)
#    2120             inputs = [arg.flat[0] for arg in args]
# -> 2121             outputs = func(*inputs)
#    2122
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/dates.py in _to_ordinalf(dt)
#     221
# --> 222     base = float(dt.toordinal())
#     223
#
# AttributeError: 'numpy.str_' object has no attribute 'toordinal'
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# <ipython-input-664-21be6f22be75> in <module>
#      11 ax = sns.lineplot(x = df_graph.index, y = df_graph['count_event'], ax = ax2, color = 'orange')
#      12
# ---> 13 ax.set(xlabel="Date",
#      14        ylabel="Energy in (kWh)",
#      15        title="Sum of Energy per Week For 2014",
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/artist.py in set(self, **kwargs)
#    1099             sorted(kwargs.items(), reverse=True,
#    1100                    key=lambda x: (self._prop_order.get(x[0], 0), x[0])))
# -> 1101         return self.update(props)
#    1102
#    1103     def findobj(self, match=None, include_self=True):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/artist.py in update(self, props)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/artist.py in <listcomp>(.0)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/artist.py in _update_property(self, k, v)
#    1001                     raise AttributeError('{!r} object has no property {!r}'
#    1002                                          .format(type(self).__name__, k))
# -> 1003                 return func(v)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in set_xlim(self, left, right, emit, auto, xmin, xmax)
#    3182
#    3183         self._process_unit_info(xdata=(left, right))
# -> 3184         left = self._validate_converted_limits(left, self.convert_xunits)
#    3185         right = self._validate_converted_limits(right, self.convert_xunits)
#    3186
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in _validate_converted_limits(self, limit, convert)
#    3096         """
#    3097         if limit is not None:
# -> 3098             converted_limit = convert(limit)
#    3099             if (isinstance(converted_limit, Real)
#    3100                     and not np.isfinite(converted_limit)):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/artist.py in convert_xunits(self, x)
#     176         if ax is None or ax.xaxis is None:
#     177             return x
# --> 178         return ax.xaxis.convert_units(x)
#     179
#     180     def convert_yunits(self, y):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axis.py in convert_units(self, x)
#    1573             ret = self.converter.convert(x, self.units, self)
#    1574         except Exception as e:
# -> 1575             raise munits.ConversionError('Failed to convert value(s) to axis '
#    1576                                          f'units: {x!r}') from e
#    1577         return ret
#
# ConversionError: Failed to convert value(s) to axis units: '2014-01-01'

# %%
# charging per month 
# sum of energy
# show varables

# %%
# Sum of Energy per Day For 2014



sns.lineplot(
    x = df_graph.index, y = df_graph['Energy (kWh)']

);
# Axis labels
plt.xlabel("Date", fontsize = 18)
plt.ylabel("Energy (kWh)", fontsize = 18)
plt.title('Sum of Energy per Day For 2014 ', fontsize = 21)

plt.gcf().autofmt_xdate()

date_format = mdates.DateFormatter('%d-%m-%Y')
plt.gca().xaxis.set_major_formatter(date_format)
plt.gca().xaxis.set_major_locator(mdates.WeekdayLocator(interval=4))
    # ax.xaxis.set_minor_locator(mdates.DayLocator())
;
# Out:
# ''

# %%
sns.scatterplot(data = df, y = 'Energy (kWh)', x = 'week', )

# %% [markdown]
# ## Questions
# <hr>

# %%
"""
Date can be used to say when and how much load is put on the Grid
Q ?what is the best way to show time on a graph?
Q ?Show amount of energy used per time 
Q ?is there a normal time period when people charge and how much do they charge?
Q ? do users charge normal at the same time?  what is the propability they keep to their pattern? 

        Math to show consitensy 

Q Is there more charge from a particular user zip code?
Q what if we log that charge that it is not taking place at their home charging
Q most popular 'driver postal code'
Q 

basic questions

averge fee 
averge charging time
driver postal code. 

most popular Port type
avg charing time & energy === per port type 

"""

"""
Questons about the data 

how are they computing GHG savings in (KG)
how are they computing Gasoline savings (gallons)

"""
# Out:
# '\nQuestons about the data \n\nhow are they computing GHG savings in (KG)\nhow are they computing Gasoline savings (gallons)\n\n'
